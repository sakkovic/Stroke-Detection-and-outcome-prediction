# %% [markdown]
# # import libraries

# %%
import tensorflow as tf
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy
import cv2
from tensorflow.keras.models import load_model
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# # . Load Data

# %%
print('hi')
# Out:
# hi

# %%
data = tf.keras.utils.image_dataset_from_directory('data',color_mode='grayscale')
# Out:
# Found 2501 files belonging to 2 classes.

# %%
data_iterator = data.as_numpy_iterator()

# %%
batch = data_iterator.next()

# %%
batch[0].shape
# Out:
# (32, 256, 256, 1)

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# # 4. Scale Data

# %%
# data = data.map(lambda x,y: (x/255, y))

# %%
# data.as_numpy_iterator().next()

# %% [markdown]
# # 5. Split Data

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)
test_size = int(len(data)*.1)

# %%
train_size
# Out:
# 55

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# # 6. Build Deep Learning Model

# %%
train
# Out:
# <TakeDataset element_spec=(TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,1)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      160
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,337
# Trainable params: 3,696,337
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 7. Train

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 55/55 [==============================] - 32s 561ms/step - loss: 1.1515 - accuracy: 0.8545 - val_loss: 0.2122 - val_accuracy: 0.9208
# Epoch 2/20
# 55/55 [==============================] - 30s 536ms/step - loss: 0.1622 - accuracy: 0.9301 - val_loss: 0.1310 - val_accuracy: 0.9667
# Epoch 3/20
# 55/55 [==============================] - 30s 552ms/step - loss: 0.0896 - accuracy: 0.9659 - val_loss: 0.1210 - val_accuracy: 0.9708
# Epoch 4/20
# 55/55 [==============================] - 30s 549ms/step - loss: 0.0493 - accuracy: 0.9818 - val_loss: 0.1009 - val_accuracy: 0.9750
# Epoch 5/20
# 55/55 [==============================] - 30s 540ms/step - loss: 0.0477 - accuracy: 0.9835 - val_loss: 0.0873 - val_accuracy: 0.9750
# Epoch 6/20
# 55/55 [==============================] - 37s 664ms/step - loss: 0.0316 - accuracy: 0.9920 - val_loss: 0.0631 - val_accuracy: 0.9771
# Epoch 7/20
# 55/55 [==============================] - 55s 999ms/step - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.0702 - val_accuracy: 0.9771
# Epoch 8/20
# 55/55 [==============================] - 52s 936ms/step - loss: 0.0134 - accuracy: 0.9960 - val_loss: 0.0411 - val_accuracy: 0.9854
# Epoch 9/20
# 55/55 [==============================] - 54s 972ms/step - loss: 0.0108 - accuracy: 0.9972 - val_loss: 0.0764 - val_accuracy: 0.9771
# Epoch 10/20
# 55/55 [==============================] - 53s 954ms/step - loss: 0.0144 - accuracy: 0.9960 - val_loss: 0.0592 - val_accuracy: 0.9708
# Epoch 11/20
# 55/55 [==============================] - 55s 995ms/step - loss: 0.0132 - accuracy: 0.9960 - val_loss: 0.0967 - val_accuracy: 0.9708
# Epoch 12/20
# 55/55 [==============================] - 52s 951ms/step - loss: 0.0174 - accuracy: 0.9949 - val_loss: 0.0577 - val_accuracy: 0.9833
# Epoch 13/20
# 55/55 [==============================] - 47s 851ms/step - loss: 0.0073 - accuracy: 0.9989 - val_loss: 0.0961 - val_accuracy: 0.9708
# Epoch 14/20
# 55/55 [==============================] - 31s 567ms/step - loss: 0.0123 - accuracy: 0.9983 - val_loss: 0.0452 - val_accuracy: 0.9833
# Epoch 15/20
# 55/55 [==============================] - 32s 580ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 0.0591 - val_accuracy: 0.9875
# Epoch 16/20
# 55/55 [==============================] - 32s 577ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 0.0377 - val_accuracy: 0.9875
# Epoch 17/20
# 55/55 [==============================] - 32s 585ms/step - loss: 5.4080e-04 - accuracy: 1.0000 - val_loss: 0.0600 - val_accuracy: 0.9812
# Epoch 18/20
# 55/55 [==============================] - 32s 579ms/step - loss: 3.3027e-04 - accuracy: 1.0000 - val_loss: 0.0773 - val_accuracy: 0.9812
# Epoch 19/20
# 55/55 [==============================] - 32s 576ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0739 - val_accuracy: 0.9812
# Epoch 20/20
# 55/55 [==============================] - 33s 601ms/step - loss: 0.0156 - accuracy: 0.9977 - val_loss: 0.0712 - val_accuracy: 0.9833

# %% [markdown]
# # 8. Plot Performance

# %%
fig = plt.figure()
plt.plot(hist.history['loss'], color='teal', label='loss')
plt.plot(hist.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(hist.history['accuracy'], color='teal', label='accuracy')
plt.plot(hist.history['val_accuracy'], color='orange', label='val_accuracy')
fig.suptitle('Accuracy', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# # 9. Evaluate

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test.as_numpy_iterator(): 
    X, y = batch
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 0s 238ms/step
# 1/1 [==============================] - 0s 150ms/step
# 1/1 [==============================] - 0s 188ms/step
# 1/1 [==============================] - 0s 214ms/step
# 1/1 [==============================] - 0s 245ms/step
# 1/1 [==============================] - 0s 187ms/step
# 1/1 [==============================] - 0s 172ms/step

# %%
print(pre.result(), re.result(), acc.result())
# Out:
# tf.Tensor(1.0, shape=(), dtype=float32) tf.Tensor(0.8888889, shape=(), dtype=float32) tf.Tensor(0.98660713, shape=(), dtype=float32)

# %% [markdown]
# # 10. Test

# %%
img = cv2.imread('stroketest.jpg',0)
plt.imshow(img)
plt.show()

# %%
new_size = (256,256)
resize = cv2.resize(img, new_size)
plt.imshow(resize)
plt.show()

# %%
yhat = model.predict(np.expand_dims(resize,0))
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
yhat
# Out:
# array([[0.65506047]], dtype=float32)

# %%
if yhat > 0.5: 
    print(f'Predicted class is stroke')
else:
    print(f'Predicted class is normale')
# Out:
# Predicted class is stroke

# %% [markdown]
# # 11. Save the Model

# %%
model.save(os.path.join('models','imageclassifier.h5'))

# %%
new_model = load_model(os.path.join('models','imageclassifier.h5'))

# %%
yhatnew=new_model.predict(np.expand_dims(resize, 0))
yhatnew
# Out:
# 1/1 [==============================] - 0s 22ms/step
# array([[8.934131e-06]], dtype=float32)

# %%
if yhatnew > 0.5: 
    print(f'Predicted class is stroke')
else:
    print(f'Predicted class is normale')
# Out:
# Predicted class is normale
